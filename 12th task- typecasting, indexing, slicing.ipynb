# %% [markdown]
# # 12th

# %% [markdown]
# # casting,indexing,slicing

# %%
s3 = 'welcometeam'
s3
# Out:
# 'welcometeam'

# %%
s3[1:5]
# Out:
# 'elco'

# %%
s3[1:8:3]
# Out:
# 'eot'

# %%
s3[1:10:3]
# Out:
# 'eot'

# %%
s3[::2]
# Out:
# 'wloeem'

# %%
s3[::3]
# Out:
# 'wcea'

# %% [markdown]
# # backward slicing

# %%
s3[::-2]
# Out:
# 'meeolw'

# %%
s3[::-1]
# Out:
# 'maetemoclew'

# %%
s3[-1:-6:-2]
# Out:
# 'mee'

# %%
s3[-1:-10:-1]
# Out:
# 'maetemocl'

# %% [markdown]
# # casting other data types to integer

# %%
# float to int conversion
int(2.3)
# Out:
# 2

# %%
#boolean to int
int(True)
# Out:
# 1

# %%
# complex to integer
int(5+9j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # complex to integer
# ----> 2 int(5+9j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
# conversion ofcomplex datatype to integer is not possible

# %%
# textstring to int
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # textstring to int
# ----> 2 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
# conversion of text string to integer is not possible

# %%
# string to int
int('10')
# Out:
# 10

# %% [markdown]
# # other datatype to float

# %%
# float of integer
float(20)
# Out:
# 20.0

# %%
# float of boolean
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
# float of string
float('20')
# Out:
# 20.0

# %%
#float of text string
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 #float of text string
# ----> 2 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
# float of complex datatype
float(5+9j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # float of complex datatype
# ----> 2 float(5+9j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # other datatypes to bool

# %%
# bool of integer
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(20)
# Out:
# True

# %%
# bool of complex
bool(5+9j)
# Out:
# True

# %%
# bool of string
bool('10')
# Out:
# True

# %%
# bool of text string
bool('ten')
# Out:
# True

# %%
bool('zero')
# Out:
# True

# %%
bool(zero)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 bool(zero)
#
# NameError: name 'zero' is not defined

# %%
# bool of float
bool(3.6)
# Out:
# True

# %%
# bool of empty()
bool( )
# Out:
# False
