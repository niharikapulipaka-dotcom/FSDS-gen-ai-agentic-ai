# %% [markdown]
# # variable declaration in python

# %%
# Python variable declaration and assign value (name=value)
nit = 1030
nit
# Out:
# 1030

# %%
# Python variable name should not start with a number
1030 = nit
# Out:
#   Cell In[4], line 1
#     1030 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# Python variable name should not start with a number
1nit = 10 
1nit
# Out:
#   Cell In[5], line 1
#     1nit = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
#Python variable name can have number at the end
nit1 = 100
nit1
# Out:
# 100

# %%
# Python variable names are case sensitive
nit = 20
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 nit = 20
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 20

# %%
# Python variable name should not contain special characters other than _
nit@ = 8 
nit@
# Out:
#   Cell In[9], line 2
#     nit@ = 8
#          ^
# SyntaxError: invalid syntax

# %%
# Python variable name should not contain special characters other than _
nit_= 8 
nit_
# Out:
# 8

# %%
# Python variable name should not contain special characters other than _

_nit= 8 
_nit
# Out:
# 8

# %%
# Python keyword list

import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
#pyhthon variable name should not use keywords

for = 45
for
# Out:
#   Cell In[16], line 1
#     for = 45
#         ^
# SyntaxError: invalid syntax

# %%
For = 50
For
# Out:
# 50

# %%
if = 67
# Out:
#   Cell In[18], line 1
#     if = 67
#        ^
# SyntaxError: invalid syntax

# %%
If = 67
If
# Out:
# 67

# %%
else = 7
# Out:
#   Cell In[21], line 1
#     else = 7
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 10th--python datatypes

# %%
i = 5 
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
# integer datatype

type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140710759736360

# %%
# float datatype

f = 110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
gold_price = 14800.78
gold_price
# Out:
# 14800.78

# %%
type(gold_price)
# Out:
# float

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
# print datatype

print(10+5)
print(10-5)
print(10*5)
# Out:
# 15
# 5
# 50

# %%
# float datatype with exponential

f1 = 2.4e1
f1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f2 = 3.5e3
f2
# Out:
# 3500.0

# %% [markdown]
# # boolean datatype

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
# float division
False / True
# Out:
# 0.0

# %%
False// True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # complex datatype

# %%
c = 10 + 20j # 10 - real part & 20 imaginary part where j = squre root of -1 
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c = 10 + 20j 
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# # 11th

# %% [markdown]
# # integer, float, complex, sting, bool

# %%
a=4
a
# Out:
# 4

# %%
type(a)
# Out:
# int

# %%
b=5.9
b
# Out:
# 5.9

# %%
Type(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Type(b)
#
# NameError: name 'Type' is not defined

# %%
type(b)
# Out:
# float

# %%
a=True
a1=False
b=a+a1
b
# Out:
# 1

# %%
type(b)
# Out:
# int

# %%
True + False
# Out:
# 1

# %%
b = False
type(b)
# Out:
# bool

# %%
k=true
type(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 k=true
#       2 type(k)
#
# NameError: name 'true' is not defined

# %%
k=True
type(k)
# Out:
# bool

# %%
c = 5+6j
c
# Out:
# (5+6j)

# %%
type(c)
# Out:
# complex

# %%
c
# Out:
# (5+6j)

# %%
c.real
# Out:
# 5.0

# %%
c.imaginary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 c.imaginary
#
# AttributeError: 'complex' object has no attribute 'imaginary'

# %%
c.imag
# Out:
# 6.0

# %%
c
# Out:
# (5+6j)

# %%
h= 2+3j
h
# Out:
# (2+3j)

# %%
c+h
# Out:
# (7+9j)

# %%
print(c)
print(h)
# Out:
# (5+6j)
# (2+3j)

# %%
print(c+h)
# Out:
# (7+9j)

# %% [markdown]
# # string

# %%
welcome to nareshit & request everyone please subscr nareshit youtube, instagram
# Out:
#   Cell In[30], line 1
#     welcome to nareshit & request everyone please subscr nareshit youtube, instagram
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to nareshit & request everyone please subscr nareshit youtube, instagram'
# Out:
# 'welcome to nareshit & request everyone please subscr nareshit youtube, instagram'

# %%
"welcome to nareshit & request everyone please subscr nareshit youtube, instagram"
# Out:
# 'welcome to nareshit & request everyone please subscr nareshit youtube, instagram'

# %%
'''welcome to nareshit & request everyone please subscr nareshit youtube, instagram'''
# Out:
# 'welcome to nareshit & request everyone please subscr nareshit youtube, instagram'

# %%
''''welcome to nareshit & request everyone please subscr nareshit youtube, instagram''''
# Out:
#   Cell In[34], line 1
#     ''''welcome to nareshit & request everyone please subscr nareshit youtube, instagram''''
#                                                                                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'welcome to nareshit 
request everyone please 
subscr nareshit youtube, instagram'
# Out:
#   Cell In[35], line 1
#     'welcome to nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"welcome to nareshit 
request everyone please 
subscr nareshit youtube, instagram"
# Out:
#   Cell In[36], line 1
#     "welcome to nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome to nareshit 
request everyone please 
subscr nareshit youtube, instagram'''
# Out:
# 'welcome to nareshit \nrequest everyone please \nsubscr nareshit youtube, instagram'

# %% [markdown]
# # string indexing

# %% [markdown]
# # string forward indexing

# %%
s = 'python'
s
# Out:
# 'python'

# %%
s1 = 'welcome'
s1
# Out:
# 'welcome'

# %%
s1[3]
# Out:
# 'c'

# %%
s1[6]
# Out:
# 'e'

# %%
s1[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s1[9]
#
# IndexError: string index out of range

# %% [markdown]
# # string backward indexing

# %%
s1
# Out:
# 'welcome'

# %%
s1[-2]
# Out:
# 'm'

# %%
s1[-5]
# Out:
# 'l'

# %%
s1[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s1[-8]
#
# IndexError: string index out of range

# %%
len(s1)
# Out:
# 7

# %%
s1[0]
# Out:
# 'w'

# %%
s1
# Out:
# 'welcome'

# %% [markdown]
# # forward slicing

# %%
s1[:]
# Out:
# 'welcome'

# %%
s1[3:]
# Out:
# 'come'

# %%
s1[:6]
# Out:
# 'welcom'

# %%
s1[2:5]
# Out:
# 'lco'

# %%
name= 'mynameisniharika'
name
# Out:
# 'mynameisniharika'

# %%
name[:]
# Out:
# 'mynameisniharika'

# %%
len(name)
# Out:
# 16

# %%
name[6:16]
# Out:
# 'isniharika'

# %%
name[:15]
# Out:
# 'mynameisniharik'

# %%
name[4:]
# Out:
# 'meisniharika'

# %%
name[3:10:3]
# Out:
# 'aii'
